# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
plt.plot([1, 3, 2, 4])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title('Test Plot', fontsize=23, color='lime')
plt.xlabel('number n')
plt.ylabel('sardor')
plt.show()

# %% [markdown]
# # Shakl o'lchamini o'zgartiring. qizil nuqtalarni chizish; o'qi o'lchovlarini x: 0-6 va y: 0-20 ga o'rnating

# %%
plt.figure(figsize=(2,5))                   # 2 inches wide x 5 inches tall
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # red-o
plt.axis([0, 10, 0, 20]) # [xmin, xmax, ymin, ymax]
plt.annotate('square it', (1,6))
plt.show()

# %% [markdown]
# #  bar

# %%
plt.clf()          # clear figure
x = np.arange(4)
y = [8.8, 5.2, 3.6, 5.9]
plt.xticks(x, ('Ankit', 'Hans', 'Joe', 'Flaco'))
# plt.bar(x, y)
# plt.bar(x, y, color='y')
plt.bar(x, y, color=['lime', 'r', 'k', 'm'])
plt.show()

# %%
d = {'Red O' : np.random.rand(10),
     'Grn X' : np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style=['ro','gx'])
plt.show()

# %% [markdown]
# # Vaqt seriyasi - olti oylik tasodifiy floats

# %%
ts = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2018', periods=180))
df = pd.DataFrame(np.random.randn(180, 3), index=ts.index, columns=list('ABC'))
df.cumsum().plot()
plt.show()

# %% [markdown]
# # alpha degani fonni yani vizualizatsiyani hiraligi yani shaffofligi ni bildirdi 1 bo'sa polni ozini rangi 0ga qarab ketilsa hiralashib boradi

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30 * np.random.rand(N))**2   # 0 to 15 point radii
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # plt

# %%
df = pd.read_csv('Fremont_weather.txt')
print(df)
plt.bar(df['month'], df['record_high'], color='r')
plt.bar(df['month'], df['record_low'], color='c')
plt.plot(df['month'], df['avg_high'], color='k')
plt.plot(df['month'], df['avg_low'], color='b')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58       42           74          22               2.95
# 1    Feb        61       45           78          26               3.02
# 2    Mar        65       48           84          25               2.34
# 3    Apr        67       50           92          28               1.02
# 4    May        71       53           98          35               0.48
# 5    Jun        75       56          107          41               0.11
# 6    Jul        77       58          105          44               0.00
# 7    Aug        77       59          102          43               0.03
# 8    Sep        77       57          103          40               0.17
# 9    Oct        73       54           96          34               0.81
# 10   Nov        64       48           84          30               1.70
# 11   Dec        58       42           73          21               2.56

# %%
fig = plt.figure()
fig.suptitle('My SubPlots')
fig.add_subplot(221)
plt.plot([np.log(n) for n in range(1,10)])
fig.add_subplot(222, facecolor='y')
fig.add_subplot(223)
fig.add_subplot(224) 
plt.show()

# %%
fig, plots = plt.subplots(2, sharex=True)
fig.suptitle('Sharing X axis')
x = range(0,200,5)
y = [n**0.8 for n in x]
plots[0].plot(x, y, color='r')
plots[1].scatter(x, y)
plt.show()

# %%
plt.figure(figsize=(4,3), dpi=100)
plt.plot([245, 170, 148, 239, 161, 196, 112, 258])
plt.axis([0, 7, 0, 300])
plt.title('Flight Data')
plt.xlabel('Speed')
plt.savefig('Flights.png')
plt.show()
